# %% [markdown]
# # DataKind Red Cross Project ACS Quickstart

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Data Import and Cleaning

# %%
# !pwd
# Out:
# /Users/flatironschol/rcp2/rcp2/notebooks

# %%
acs_block_df = pd.read_csv('../../data/ACS 5YR Block Group Data.csv', dtype = {'GEOID': int})

# %%
acs_block_df.describe().T
# Out:
#                         count          mean           std           min  \
# GEOID                217739.0  2.811822e+11  1.572133e+11  1.001020e+10
# tot_population       217739.0  1.437724e+03  9.414765e+02  0.000000e+00
# in_poverty           217739.0  2.096563e+02  2.299371e+02  0.000000e+00
# inc_pct_poverty      216314.0  1.561501e-01  1.433608e-01  0.000000e+00
# inc_pcincome         216587.0  3.109235e+04  1.792841e+04  3.200000e+01
# ...                       ...           ...           ...           ...
# house_val_500K_750K  213107.0  6.805560e-02  1.372466e-01  0.000000e+00
# house_val_750K_1M    213107.0  2.733329e-02  8.124909e-02  0.000000e+00
# house_val_1M_1.5M    213107.0  1.533733e-02  5.896114e-02  0.000000e+00
# house_val_1.5M_2M    213107.0  5.570468e-03  3.181212e-02  0.000000e+00
# house_val_more_2M    213107.0  8.354470e-03  5.037413e-02  0.000000e+00
#
#                               25%           50%           75%           max
# ...

# %%
acs_block_df.head()
# Out:
#           GEOID   county_name  state_name  \
# 0  530020000000  Adams County  Washington
# 1  530020000000  Adams County  Washington
# 2  530020000000  Adams County  Washington
# 3  530020000000  Adams County  Washington
# 4  530020000000  Adams County  Washington
#
#                                                 NAME  tot_population  \
# 0  Block Group 1, Census Tract 9501, Adams County...             842
# 1  Block Group 2, Census Tract 9501, Adams County...             922
# 2  Block Group 3, Census Tract 9501, Adams County...             515
# 3  Block Group 1, Census Tract 9502, Adams County...             530
# 4  Block Group 2, Census Tract 9502, Adams County...             679
#
#    in_poverty  inc_pct_poverty  inc_pcincome  age_pct_under25  age_pct_25_64  \
# 0          64         0.076010       28484.0         0.738717       0.494062
# 1          94         0.101952       29939.0         0.737219       0.572597
# ...

# %%
len(acs_block_df.GEOID.unique())
# Out:
# 42935

# %%
acs_block_c4_34_df = acs_block_df.iloc[:, 4:34]
acs_block_c4_34_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217739 entries, 0 to 217738
# Data columns (total 30 columns):
# tot_population             217739 non-null int64
# in_poverty                 217739 non-null int64
# inc_pct_poverty            216314 non-null float64
# inc_pcincome               216587 non-null float64
# age_pct_under25            216690 non-null float64
# age_pct_25_64              216690 non-null float64
# age_pct_over65             216690 non-null float64
# educ_tot_pop               217739 non-null int64
# educ_no_school             216651 non-null float64
# educ_nursery_4th           216651 non-null float64
# educ_5th_6th               216651 non-null float64
# educ_7th_8th               216651 non-null float64
# educ_9th                   216651 non-null float64
# educ_10th                  216651 non-null float64
# educ_11th                  216651 non-null float64
# educ_12th_no_diploma       216651 non-null float64
# ...

# %%
fig, axs = plt.subplots(6, 5, figsize = [20, 20])
for i in range(6):
    for j in range(5):
        sns.distplot(acs_block_c4_34_df.iloc[:, (i*5)+j].dropna(), kde = False, ax = axs[i, j])
plt.savefig('../../data/acs_cols_3_34_dist')
