# %%
# this code takes the NFIRS Dataset and outputs a count of fires by GEOID -
# - The results are functionally the same as fires by census tract but saving by GEOID allows 
# us to combine with shapefiles which use GEOID
#
# requires NFIRS_2009_2016_geocoded_with_tract.csv to be in the main path

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import datetime

# %%
# Change to your filepath to data and uncomment if NFIRS_2009_2016_geocoded_with_tract.csv not in the main path 
os.chdir('..//Data//Transformed')
os.getcwd()
# Out:
# '/Users/kelson/Documents/DataKind/Red_Cross_Fire/Data/Transformed'

# %%
NFIR = pd.read_csv('NFIRS_2009_2016_Combined_Census_Tract.csv',
                   encoding='latin_1',
                   index_col=0,
                   low_memory=False)

# %%
NFIR.head()
# Out:
#          state   fdid inc_no    city            street   zip5  lat  lon  fips  \
# ID
# rcp2_id1    AK  11100    211  JUNEAU    1700 ANGUS WAY  99801  NaN  NaN   NaN
# rcp2_id2    AK  11100    470  JUNEAU  3221 PIONEER AVE  99801  NaN  NaN   NaN
# rcp2_id3    AK  11100    556  JUNEAU   10231 HERON WAY  99801  NaN  NaN   NaN
# rcp2_id4    AK  11100   1315  JUNEAU  6590 GLACIER HWY  99801  NaN  NaN   NaN
# rcp2_id5    AK  11100   2151  JUNEAU  6590 GLACIER HWY  99801  NaN  NaN   NaN
#
#                    inc_date    ...      NAME        NAMELSAD  \
# ID                             ...
# rcp2_id1   1/3/2009 0:00:00    ...       5.0  Census Tract 5
# rcp2_id2   1/6/2009 0:00:00    ...       6.0  Census Tract 6
# rcp2_id3   1/6/2009 0:00:00    ...       1.0  Census Tract 1
# rcp2_id4  1/13/2009 0:00:00    ...       4.0  Census Tract 4
# rcp2_id5  1/21/2009 0:00:00    ...       4.0  Census Tract 4
#
#                                ORIGINAL_ADDRESS  STATE  TIGER_LINE_ID  \
# ID
# rcp2_id1      1700 ANGUS WAY, JUNEAU, AK, 99801     AK    190964136.0
# rcp2_id2    3221 PIONEER AVE, JUNEAU, AK, 99801     AK    190966361.0
# rcp2_id3     10231 HERON WAY, JUNEAU, AK, 99801     AK    190962538.0
# rcp2_id4  6590 GLACIER HWY, JUNEAU,  AK,  99801     AK    190963741.0
# rcp2_id5  6590 GLACIER HWY, JUNEAU,  AK,  99801     AK    190963741.0
#
#           TIGER_LINE_SIDE  TRACTCE          X          Y state_fips
# ID
# rcp2_id1                R    500.0 -134.42440  58.306507        2.0
# rcp2_id2                R    600.0 -134.43314  58.292686        2.0
# rcp2_id3                R    100.0 -134.60330  58.402610        2.0
# rcp2_id4                R    400.0 -134.51932  58.358955        2.0
# rcp2_id5                R    400.0 -134.51932  58.358955        2.0
#
# [5 rows x 45 columns]

# %%
NFIR['GEOID'] = NFIR['GEOID'].astype('str')
NFIR.rename(columns ={'state':'COUNT'}, inplace =True)

# %%
 OUT = NFIR.groupby(['GEOID'])['COUNT'].count() 
# the selection of state is arbitrary except we know that it should excist in all entries

# %%
OUT.head()
# Out:
# GEOID
# 10001040100.0    16
# 10001040201.0    26
# 10001040202.0    89
# 10001040203.0    90
# 10001040501.0    73
# Name: COUNT, dtype: int64

# %%
OUT.to_csv('../Transformed/Fires_by_GEOID.csv',header= True)

# %%
# Out:
#                COUNT   fdid   inc_no         city  \
# ID
# rcp2_id1          AK  11100      211       JUNEAU
# rcp2_id2          AK  11100      470       JUNEAU
# rcp2_id3          AK  11100      556       JUNEAU
# rcp2_id4          AK  11100     1315       JUNEAU
# rcp2_id5          AK  11100     2151       JUNEAU
# rcp2_id6          AK  11100     3076       JUNEAU
# rcp2_id7          AK  11100     6358       JUNEAU
# rcp2_id8          AK  11100     6359       JUNEAU
# rcp2_id9          AK  11100     7620       JUNEAU
# rcp2_id10         AK  11100     8365       JUNEAU
# rcp2_id11         AK  11100     9060       JUNEAU
# rcp2_id12         AK  11100    12697       JUNEAU
# rcp2_id13         AK  11100    16498       JUNEAU
# rcp2_id14         AK  11100   164980       JUNEAU
# rcp2_id15         AK  11100    19783       JUNEAU
# rcp2_id16         AK  11100    19832       JUNEAU
# rcp2_id17         AK  11100    22554       JUNEAU
# rcp2_id18         AK  11100    23193       JUNEAU
# rcp2_id19         AK  11100    23469       JUNEAU
# rcp2_id20         AK  11100    23582       JUNEAU
# rcp2_id21         AK  11100    25508       JUNEAU
# rcp2_id22         AK  11100    27526       JUNEAU
# rcp2_id23         AK  11100    29380       JUNEAU
# rcp2_id24         AK  11100    34680       JUNEAU
# rcp2_id25         AK  11100    35340       JUNEAU
# rcp2_id26         AK  11100    37786       JUNEAU
# rcp2_id27         AK  11100    38795       JUNEAU
# rcp2_id28         AK  11100    40550      DOUGLAS
# rcp2_id29         AK  11100    40942       JUNEAU
# rcp2_id30         AK  11100    42437       JUNEAU
# ...              ...    ...      ...          ...
# rcp2_id1959077    TX  XZ404  0000283      QUITMAN
# rcp2_id1959078    TX  XZ404  0000291      QUITMAN
# rcp2_id1959079    TX  XZ404  0000311      QUITMAN
# rcp2_id1959080    TX  XZ404  0000328      QUITMAN
# rcp2_id1959081    TX  XZ407  0001505       Yantis
# rcp2_id1959082    TX  XZ407  0001518       Yantis
# rcp2_id1959083    TX  XZ407  0001601       Yantis
# rcp2_id1959084    TX  XZ407  0001629       Yantis
# rcp2_id1959085    TX  ZB502  0000151       Graham
# rcp2_id1959086    TX  ZB502  0000144       Graham
# rcp2_id1959087    TX  ZB502  0000343       Graham
# rcp2_id1959088    TX  ZB502  0000403       Graham
# rcp2_id1959089    TX  ZB502  0000726       Graham
# rcp2_id1959090    TX  ZB502  0000196       Graham
# rcp2_id1959091    TX  ZB502  0000440       Graham
# rcp2_id1959092    TX  ZB502  0000538       Graham
# rcp2_id1959093    TX  ZB502  0000545       Graham
# rcp2_id1959094    TX  ZB502  0000626       Graham
# rcp2_id1959095    TX  ZC501  0000099       Zapata
# rcp2_id1959096    TX  ZC501  0000096       Zapata
# rcp2_id1959097    TX  ZC501  0000015       Zapata
# rcp2_id1959098    TX  ZC501  0000044       Zapata
# rcp2_id1959099    TX  ZC501  0000052       Zapata
# rcp2_id1959100    TX  ZC501  0000087       Zapata
# rcp2_id1959101    TX  ZC501  0000097       Zapata
# rcp2_id1959102    TX  ZC501  0000107       Zapata
# rcp2_id1959103    TX  ZC501  0000013       zapata
# rcp2_id1959104    TX  ZC501  0000049       Zapata
# rcp2_id1959105    TX  ZC501  0000072  San Ygnacio
# rcp2_id1959106    TX  ZC501  0000098       Zapata
#
#                                       street   zip5  lat  lon  fips  \
# ID
# rcp2_id1                      1700 ANGUS WAY  99801  NaN  NaN   NaN
# rcp2_id2                    3221 PIONEER AVE  99801  NaN  NaN   NaN
# rcp2_id3                     10231 HERON WAY  99801  NaN  NaN   NaN
# rcp2_id4                    6590 GLACIER HWY  99801  NaN  NaN   NaN
# rcp2_id5                    6590 GLACIER HWY  99801  NaN  NaN   NaN
# rcp2_id6                          503 5TH ST  99801  NaN  NaN   NaN
# rcp2_id7             2865 MENDENHALL LOOP RD  99801  NaN  NaN   NaN
# rcp2_id8             2865 MENDENHALL LOOP RD  99801  NaN  NaN   NaN
# rcp2_id9        1325 MENDENHALL PENINSULA RD  99801  NaN  NaN   NaN
# rcp2_id10                       5920 LUND ST  99801  NaN  NaN   NaN
# rcp2_id11                   8610 MARILYN AVE  99801  NaN  NaN   NaN
# rcp2_id12                   2531 BARRETT AVE  99801  NaN  NaN   NaN
# rcp2_id13                       817 BASIN RD  99801  NaN  NaN   NaN
# rcp2_id14                       811 BASIN RD  99801  NaN  NaN   NaN
# rcp2_id15                 4570 N DOUGLAS HWY  99801  NaN  NaN   NaN
# rcp2_id16                    4127 DOGWOOD LN  99801  NaN  NaN   NaN
# rcp2_id17               8186 THREADNEEDLE ST  99801  NaN  NaN   NaN
# rcp2_id18                  345 GASTINEAU AVE  99801  NaN  NaN   NaN
# rcp2_id19                9436 LA PEROUSE AVE  99801  NaN  NaN   NaN
# rcp2_id20           9950 STEPHEN RICHARDS DR  99801  NaN  NaN   NaN
# rcp2_id21                   1740 GLACIER AVE  99801  NaN  NaN   NaN
# rcp2_id22                      8924 BIRCH LN  99801  NaN  NaN   NaN
# rcp2_id23                       8619 TEAL ST  99801  NaN  NaN   NaN
# rcp2_id24                           800 F ST  99801  NaN  NaN   NaN
# rcp2_id25                  3700 EL CAMINO ST  99801  NaN  NaN   NaN
# rcp2_id26                       108 TROY AVE  99801  NaN  NaN   NaN
# rcp2_id27                   8602 MARILYN AVE  99801  NaN  NaN   NaN
# rcp2_id28                        660 ALTA CT  99824  NaN  NaN   NaN
# rcp2_id29                  3943 PORTAGE BLVD  99801  NaN  NaN   NaN
# rcp2_id30                         326 4TH ST  99801  NaN  NaN   NaN
# ...                                      ...    ...  ...  ...   ...
# rcp2_id1959077                       CR 3155  75783  NaN  NaN   NaN
# rcp2_id1959078                   845 CR 1987  75783  NaN  NaN   NaN
# rcp2_id1959079                  3582 CR 3250  75783  NaN  NaN   NaN
# rcp2_id1959080           3171 S STATE HWY 37  75783  NaN  NaN   NaN
# rcp2_id1959081                   470 cr 1210  75497  NaN  NaN   NaN
# rcp2_id1959082                    1980 fm17n  75497  NaN  NaN   NaN
# rcp2_id1959083                  1107 cr 1912  75497  NaN  NaN   NaN
# rcp2_id1959084                  1445 hwy 154  75497  NaN  NaN   NaN
# rcp2_id1959085             3576 Hwy 380 East  76450  NaN  NaN   NaN
# rcp2_id1959086                   815 Gregory  76450  NaN  NaN   NaN
# rcp2_id1959087                    3606 FM 61  76450  NaN  NaN   NaN
# rcp2_id1959088                254 Theresa DR  76450  NaN  NaN   NaN
# rcp2_id1959089              130 Boat Ramp Rd  76450  NaN  NaN   NaN
# rcp2_id1959090             1337 Hillcrest ST  76450  NaN  NaN   NaN
# rcp2_id1959091                 122 East Park  76450  NaN  NaN   NaN
# rcp2_id1959092                 1206 Third ST  76450  NaN  NaN   NaN
# rcp2_id1959093                1708 Dakota ST  76450  NaN  NaN   NaN
# rcp2_id1959094                309 12 Shawnee  76450  NaN  NaN   NaN
# rcp2_id1959095              361 Sierra Vista  78076  NaN  NaN   NaN
# rcp2_id1959096                1406 Juarez ST  78076  NaN  NaN   NaN
# rcp2_id1959097               105 Mira Flores  78076  NaN  NaN   NaN
# rcp2_id1959098             1006 Glenn street  78076  NaN  NaN   NaN
# rcp2_id1959099        2113 North Siesta lane  78076  NaN  NaN   NaN
# rcp2_id1959100                      429 Park  78076  NaN  NaN   NaN
# rcp2_id1959101             1403 Guerro st ST  78076  NaN  NaN   NaN
# rcp2_id1959102             867 Loma Verde RD  78076  NaN  NaN   NaN
# rcp2_id1959103               706 12th avenue  78076  NaN  NaN   NaN
# rcp2_id1959104                 231 Davis Ave  78076  NaN  NaN   NaN
# rcp2_id1959105              405 Grant street  78067  NaN  NaN   NaN
# rcp2_id1959106                  709 Ramireno  78076  NaN  NaN   NaN
#
#                           inc_date    ...         NAME              NAMELSAD  \
# ID                                    ...
# rcp2_id1          1/3/2009 0:00:00    ...         5.00        Census Tract 5
# rcp2_id2          1/6/2009 0:00:00    ...         6.00        Census Tract 6
# rcp2_id3          1/6/2009 0:00:00    ...         1.00        Census Tract 1
# rcp2_id4         1/13/2009 0:00:00    ...         4.00        Census Tract 4
# rcp2_id5         1/21/2009 0:00:00    ...         4.00        Census Tract 4
# rcp2_id6         1/29/2009 0:00:00    ...         5.00        Census Tract 5
# rcp2_id7          3/1/2009 0:00:00    ...         2.00        Census Tract 2
# rcp2_id8          3/1/2009 0:00:00    ...         2.00        Census Tract 2
# rcp2_id9         3/15/2009 0:00:00    ...         1.00        Census Tract 1
# rcp2_id10        3/23/2009 0:00:00    ...         4.00        Census Tract 4
# rcp2_id11        3/29/2009 0:00:00    ...         3.00        Census Tract 3
# rcp2_id12         5/1/2009 0:00:00    ...         1.00        Census Tract 1
# rcp2_id13         6/1/2009 0:00:00    ...         5.00        Census Tract 5
# rcp2_id14         6/1/2009 0:00:00    ...         5.00        Census Tract 5
# rcp2_id15        6/25/2009 0:00:00    ...         6.00        Census Tract 6
# rcp2_id16        6/25/2009 0:00:00    ...         2.00        Census Tract 2
# rcp2_id17        7/16/2009 0:00:00    ...         3.00        Census Tract 3
# rcp2_id18        7/21/2009 0:00:00    ...         5.00        Census Tract 5
# rcp2_id19        7/23/2009 0:00:00    ...         3.00        Census Tract 3
# rcp2_id20        7/24/2009 0:00:00    ...          NaN                   NaN
# rcp2_id21         8/7/2009 0:00:00    ...         5.00        Census Tract 5
# rcp2_id22        8/25/2009 0:00:00    ...         2.00        Census Tract 2
# rcp2_id23         9/7/2009 0:00:00    ...         3.00        Census Tract 3
# rcp2_id24       10/19/2009 0:00:00    ...         5.00        Census Tract 5
# rcp2_id25       10/24/2009 0:00:00    ...         2.00        Census Tract 2
# rcp2_id26       11/14/2009 0:00:00    ...         5.00        Census Tract 5
# rcp2_id27       11/23/2009 0:00:00    ...         3.00        Census Tract 3
# rcp2_id28        12/9/2009 0:00:00    ...         6.00        Census Tract 6
# rcp2_id29       12/13/2009 0:00:00    ...         2.00        Census Tract 2
# rcp2_id30       12/27/2009 0:00:00    ...         5.00        Census Tract 5
# ...                            ...    ...          ...                   ...
# rcp2_id1959077  10/31/2016 0:00:00    ...          NaN                   NaN
# rcp2_id1959078   11/7/2016 0:00:00    ...          NaN                   NaN
# rcp2_id1959079  11/27/2016 0:00:00    ...      9503.01  Census Tract 9503.01
# rcp2_id1959080  12/17/2016 0:00:00    ...          NaN                   NaN
# rcp2_id1959081    1/9/2016 0:00:00    ...          NaN                   NaN
# rcp2_id1959082   2/12/2016 0:00:00    ...          NaN                   NaN
# rcp2_id1959083   10/3/2016 0:00:00    ...      9503.02  Census Tract 9503.02
# rcp2_id1959084  12/29/2016 0:00:00    ...          NaN                   NaN
# rcp2_id1959085   2/28/2016 0:00:00    ...          NaN                   NaN
# rcp2_id1959086   2/24/2016 0:00:00    ...      9505.00     Census Tract 9505
# rcp2_id1959087   5/30/2016 0:00:00    ...      9504.00     Census Tract 9504
# rcp2_id1959088   6/26/2016 0:00:00    ...      9504.00     Census Tract 9504
# rcp2_id1959089  11/18/2016 0:00:00    ...      9504.00     Census Tract 9504
# rcp2_id1959090   3/21/2016 0:00:00    ...      9506.00     Census Tract 9506
# rcp2_id1959091   7/12/2016 0:00:00    ...      9504.00     Census Tract 9504
# rcp2_id1959092   8/30/2016 0:00:00    ...      9506.00     Census Tract 9506
# rcp2_id1959093    9/2/2016 0:00:00    ...      9506.00     Census Tract 9506
# rcp2_id1959094   10/1/2016 0:00:00    ...          NaN                   NaN
# rcp2_id1959095  10/10/2016 0:00:00    ...      9504.00     Census Tract 9504
# rcp2_id1959096   9/26/2016 0:00:00    ...      9503.01  Census Tract 9503.01
# rcp2_id1959097   2/10/2016 0:00:00    ...      9504.00     Census Tract 9504
# rcp2_id1959098    5/6/2016 0:00:00    ...      9503.02  Census Tract 9503.02
# rcp2_id1959099   5/25/2016 0:00:00    ...      9504.00     Census Tract 9504
# rcp2_id1959100    9/1/2016 0:00:00    ...      9504.00     Census Tract 9504
# rcp2_id1959101   10/1/2016 0:00:00    ...          NaN                   NaN
# rcp2_id1959102  10/25/2016 0:00:00    ...      9504.00     Census Tract 9504
# rcp2_id1959103    2/6/2016 0:00:00    ...      9503.02  Census Tract 9503.02
# rcp2_id1959104   5/18/2016 0:00:00    ...          NaN                   NaN
# rcp2_id1959105   7/20/2016 0:00:00    ...      9504.00     Census Tract 9504
# rcp2_id1959106   10/6/2016 0:00:00    ...      9503.01  Census Tract 9503.01
#
#                                                ORIGINAL_ADDRESS  STATE  \
# ID
# rcp2_id1                      1700 ANGUS WAY, JUNEAU, AK, 99801     AK
# rcp2_id2                    3221 PIONEER AVE, JUNEAU, AK, 99801     AK
# rcp2_id3                     10231 HERON WAY, JUNEAU, AK, 99801     AK
# rcp2_id4                  6590 GLACIER HWY, JUNEAU,  AK,  99801     AK
# rcp2_id5                  6590 GLACIER HWY, JUNEAU,  AK,  99801     AK
# rcp2_id6                          503 5TH ST, JUNEAU, AK, 99801     AK
# rcp2_id7             2865 MENDENHALL LOOP RD, JUNEAU, AK, 99801     AK
# rcp2_id8             2865 MENDENHALL LOOP RD, JUNEAU, AK, 99801     AK
# rcp2_id9        1325 MENDENHALL PENINSULA RD, JUNEAU, AK, 99801     AK
# rcp2_id10                       5920 LUND ST, JUNEAU, AK, 99801     AK
# rcp2_id11                   8610 MARILYN AVE, JUNEAU, AK, 99801     AK
# rcp2_id12                   2531 BARRETT AVE, JUNEAU, AK, 99801     AK
# rcp2_id13                       817 BASIN RD, JUNEAU, AK, 99801     AK
# rcp2_id14                       811 BASIN RD, JUNEAU, AK, 99801     AK
# rcp2_id15                 4570 N DOUGLAS HWY, JUNEAU, AK, 99801     AK
# rcp2_id16                    4127 DOGWOOD LN, JUNEAU, AK, 99801     AK
# rcp2_id17               8186 THREADNEEDLE ST, JUNEAU, AK, 99801     AK
# rcp2_id18                345 GASTINEAU AVE, JUNEAU,  AK,  99801     AK
# rcp2_id19                9436 LA PEROUSE AVE, JUNEAU, AK, 99801     AK
# rcp2_id20                                                   NaN    NaN
# rcp2_id21                   1740 GLACIER AVE, JUNEAU, AK, 99801     AK
# rcp2_id22                      8924 BIRCH LN, JUNEAU, AK, 99801     AK
# rcp2_id23                       8619 TEAL ST, JUNEAU, AK, 99801     AK
# rcp2_id24                           800 F ST, JUNEAU, AK, 99801     AK
# rcp2_id25                  3700 EL CAMINO ST, JUNEAU, AK, 99801     AK
# rcp2_id26                       108 TROY AVE, JUNEAU, AK, 99801     AK
# rcp2_id27                   8602 MARILYN AVE, JUNEAU, AK, 99801     AK
# rcp2_id28                       660 ALTA CT, DOUGLAS, AK, 99824     AK
# rcp2_id29                  3943 PORTAGE BLVD, JUNEAU, AK, 99801     AK
# rcp2_id30                         326 4TH ST, JUNEAU, AK, 99801     AK
# ...                                                         ...    ...
# rcp2_id1959077                      CR 3155, QUITMAN, TX, 75783     TX
# rcp2_id1959078                  845 CR 1987, QUITMAN, TX, 75783     TX
# rcp2_id1959079                  3582 CR 3250, QUITMAN, TX,75783     TX
# rcp2_id1959080                                              NaN    NaN
# rcp2_id1959081                   470 CR 1210, YANTIS, TX, 75497     TX
# rcp2_id1959082                                              NaN    NaN
# rcp2_id1959083                   1107 cr 1912, Yantis, TX,75497     TX
# rcp2_id1959084                  1445 HWY 154, YANTIS, TX, 75497     TX
# rcp2_id1959085                                              NaN    NaN
# rcp2_id1959086                    815 Gregory, Graham, TX,76450     TX
# rcp2_id1959087                     3606 FM 61, Graham, TX,76450     TX
# rcp2_id1959088                 254 Theresa DR, Graham, TX,76450     TX
# rcp2_id1959089               130 Boat Ramp Rd, Graham, TX,76450     TX
# rcp2_id1959090              1337 Hillcrest ST, Graham, TX,76450     TX
# rcp2_id1959091                122 East Park, Graham,  TX, 76450     TX
# rcp2_id1959092                  1206 Third ST, Graham, TX,76450     TX
# rcp2_id1959093                 1708 Dakota ST, Graham, TX,76450     TX
# rcp2_id1959094                                              NaN    NaN
# rcp2_id1959095               361 Sierra Vista, Zapata, TX,78076     TX
# rcp2_id1959096                 1406 Juarez ST, Zapata, TX,78076     TX
# rcp2_id1959097                105 Mira Flores, Zapata, TX,78076     TX
# rcp2_id1959098              1006 Glenn street, Zapata, TX,78076     TX
# rcp2_id1959099         2113 North Siesta lane, Zapata, TX,78076     TX
# rcp2_id1959100                       429 Park, Zapata, TX,78076     TX
# rcp2_id1959101             1403 GUERRO ST ST, ZAPATA, TX, 78076     TX
# rcp2_id1959102              867 Loma Verde RD, Zapata, TX,78076     TX
# rcp2_id1959103                706 12th avenue, zapata, TX,78076     TX
# rcp2_id1959104                                              NaN    NaN
# rcp2_id1959105          405 Grant street, San Ygnacio, TX,78067     TX
# rcp2_id1959106                   709 Ramireno, Zapata, TX,78076     TX
#
#                 TIGER_LINE_ID  TIGER_LINE_SIDE   TRACTCE          X  \
# ID
# rcp2_id1          190964136.0                R     500.0 -134.42440
# rcp2_id2          190966361.0                R     600.0 -134.43314
# rcp2_id3          190962538.0                R     100.0 -134.60330
# rcp2_id4          190963741.0                R     400.0 -134.51932
# rcp2_id5          190963741.0                R     400.0 -134.51932
# rcp2_id6          190964357.0                R     500.0 -134.40715
# rcp2_id7          190966975.0                R     200.0 -134.57780
# rcp2_id8          190966975.0                R     200.0 -134.57780
# rcp2_id9          190970698.0                L     100.0 -134.62810
# rcp2_id10         190963818.0                L     400.0 -134.49838
# rcp2_id11         190963170.0                R     300.0 -134.56995
# rcp2_id12         190966098.0                L     100.0 -134.60814
# rcp2_id13         190964239.0                R     500.0 -134.41136
# rcp2_id14         190964239.0                R     500.0 -134.41118
# rcp2_id15         190968370.0                L     600.0 -134.45390
# rcp2_id16         190962829.0                L     200.0 -134.56918
# rcp2_id17         190971243.0                L     300.0 -134.55470
# rcp2_id18         190971348.0                L     500.0 -134.40144
# rcp2_id19         190968438.0                L     300.0 -134.59380
# rcp2_id20                 NaN              NaN       NaN        NaN
# rcp2_id21         190971314.0                L     500.0 -134.43141
# rcp2_id22         190971129.0                R     200.0 -134.57820
# rcp2_id23         190963448.0                L     300.0 -134.57465
# rcp2_id24         190971333.0                R     500.0 -134.42172
# rcp2_id25         190962969.0                R     200.0 -134.57288
# rcp2_id26         190964131.0                L     500.0 -134.42552
# rcp2_id27         190963170.0                R     300.0 -134.56973
# rcp2_id28         190966303.0                R     600.0 -134.38528
# rcp2_id29         190970676.0                R     200.0 -134.57912
# rcp2_id30         190964351.0                L     500.0 -134.40823
# ...                       ...              ...       ...        ...
# rcp2_id1959077            NaN              NaN  950302.0  -95.45969
# rcp2_id1959078            NaN              NaN  950302.0  -95.45969
# rcp2_id1959079     42998958.0                L  950301.0  -95.38593
# rcp2_id1959080            NaN              NaN       NaN        NaN
# rcp2_id1959081            NaN              NaN  950302.0  -95.59814
# rcp2_id1959082            NaN              NaN       NaN        NaN
# rcp2_id1959083     42972789.0                R  950302.0  -95.59634
# rcp2_id1959084            NaN              NaN  950302.0  -95.59814
# rcp2_id1959085            NaN              NaN       NaN        NaN
# rcp2_id1959086    183300061.0                R  950500.0  -98.58587
# rcp2_id1959087    183312782.0                L  950400.0  -98.69415
# rcp2_id1959088    626835107.0                L  950400.0  -98.53727
# rcp2_id1959089    229754468.0                R  950400.0  -98.60026
# rcp2_id1959090    183300063.0                R  950600.0  -98.57265
# rcp2_id1959091    183306056.0                L  950400.0  -98.53966
# rcp2_id1959092    183299808.0                L  950600.0  -98.57685
# rcp2_id1959093    183300877.0                L  950600.0  -98.57677
# rcp2_id1959094            NaN              NaN       NaN        NaN
# rcp2_id1959095    185929808.0                L  950400.0  -99.25726
# rcp2_id1959096    185927570.0                R  950301.0  -99.25549
# rcp2_id1959097    185927696.0                L  950400.0  -99.26921
# rcp2_id1959098    185928037.0                R  950302.0  -99.26771
# rcp2_id1959099    611869234.0                L  950400.0  -99.25732
# rcp2_id1959100    645473172.0                L  950400.0  -99.25106
# rcp2_id1959101            NaN              NaN  950302.0  -99.26348
# rcp2_id1959102    636338770.0                L  950400.0  -99.25941
# rcp2_id1959103    185927959.0                R  950302.0  -99.26514
# rcp2_id1959104            NaN              NaN       NaN        NaN
# rcp2_id1959105    185934195.0                L  950400.0  -99.44025
# rcp2_id1959106    185927625.0                L  950301.0  -99.26238
#
#                         Y state_fips
# ID
# rcp2_id1        58.306507        2.0
# rcp2_id2        58.292686        2.0
# rcp2_id3        58.402610        2.0
# rcp2_id4        58.358955        2.0
# rcp2_id5        58.358955        2.0
# rcp2_id6        58.303513        2.0
# rcp2_id7        58.376774        2.0
# rcp2_id8        58.376774        2.0
# rcp2_id9        58.352090        2.0
# rcp2_id10       58.360416        2.0
# rcp2_id11       58.378548        2.0
# rcp2_id12       58.369190        2.0
# rcp2_id13       58.306053        2.0
# rcp2_id14       58.305610        2.0
# rcp2_id15       58.307533        2.0
# rcp2_id16       58.395706        2.0
# rcp2_id17       58.398570        2.0
# rcp2_id18       58.298540        2.0
# rcp2_id19       58.362160        2.0
# rcp2_id20             NaN        NaN
# rcp2_id21       58.306526        2.0
# rcp2_id22       58.392803        2.0
# rcp2_id23       58.360516        2.0
# rcp2_id24       58.300133        2.0
# rcp2_id25       58.387424        2.0
# rcp2_id26       58.305653        2.0
# rcp2_id27       58.378548        2.0
# rcp2_id28       58.268960        2.0
# rcp2_id29       58.389736        2.0
# rcp2_id30       58.302513        2.0
# ...                   ...        ...
# rcp2_id1959077  32.804780       48.0
# rcp2_id1959078  32.804780       48.0
# rcp2_id1959079  32.753130       48.0
# rcp2_id1959080        NaN        NaN
# rcp2_id1959081  32.902040       48.0
# rcp2_id1959082        NaN        NaN
# rcp2_id1959083  32.919160       48.0
# rcp2_id1959084  32.902040       48.0
# rcp2_id1959085        NaN        NaN
# rcp2_id1959086  33.092150       48.0
# rcp2_id1959087  33.140950       48.0
# rcp2_id1959088  33.057210       48.0
# rcp2_id1959089  33.129720       48.0
# rcp2_id1959090  33.092560       48.0
# rcp2_id1959091  33.119880       48.0
# rcp2_id1959092  33.105820       48.0
# rcp2_id1959093  33.084390       48.0
# rcp2_id1959094        NaN        NaN
# rcp2_id1959095  26.871280       48.0
# rcp2_id1959096  26.922910       48.0
# rcp2_id1959097  26.918790       48.0
# rcp2_id1959098  26.905940       48.0
# rcp2_id1959099  26.859910       48.0
# rcp2_id1959100  26.870770       48.0
# rcp2_id1959101  26.898340       48.0
# rcp2_id1959102  26.864210       48.0
# rcp2_id1959103  26.910210       48.0
# rcp2_id1959104        NaN        NaN
# rcp2_id1959105  27.043630       48.0
# rcp2_id1959106  26.920530       48.0
#
# [1959106 rows x 45 columns]
