# %%
#  This code takes three NFIRS datasets located in 03_geocodes of the Red Cross google drive
# and combines it into one dataset for CENSUS BLOCKS
# - Kelson Shilling-Scrivo 2019

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
# Change to your filepath to data and uncomment if NFIRS_2009_2016_geocoded_with_tract.csv not in the main path 

os.chdir('..')
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/Users/kelson/Documents/GitHub/rcp2/Code'

# %%
# load the data 

# all code is located in the Google Drive under 03_geocodes 
#https://drive.google.com/open?id=1n939Tckv0SFBSiABwIH64M6FSDJHt0eF

# NFIR = automatically geocoded data
# NFIR_2 = handcoded data 
# NFIR_orig = the original NFIRS dataset


NFIR = pd.read_csv("../Data/Raw/NFIRS_2009_2016_Geocodes_CensusBlock.csv",
                   encoding='latin_1',
                   index_col=0,
                   low_memory = False)


NFIR_orig = pd.read_csv("../Data/Raw/NFIRS_2009_2016.csv",
                   encoding='latin_1',
                   index_col=0,
                   low_memory=False)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
list(NFIR_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d128904d3cd3> in <module>()
# ----> 1 list(NFIR_2)
#
# NameError: name 'NFIR_2' is not defined

# %%
# Out:
# ['Address',
#  'City',
#  'STATE',
#  'ZIP',
#  'X.summary.',
#  'X.addressee.',
#  'X.delivery_line_1.',
#  'X.delivery_line_2.',
#  'X.city_name.',
#  'X.state_abbreviation.',
#  'X.full_zipcode.',
#  'X.latitude.',
#  'X.longitude.',
#  'ID',
#  'state_fips',
#  'COUNTYFP',
#  'TRACTCE',
#  'GEOID',
#  'NAME',
#  'NAMELSAD',
#  'MTFCC',
#  'FUNCSTAT',
#  'X',
#  'Y',
#  'rownum',
#  'STATEFP',
#  'BLKGRPCE',
#  'ALAND',
#  'AWATER',
#  'INTPTLAT',
#  'INTPTLON']

# %%
np.unique(np.floor(np.log10(NFIR['GEOID'].values)))
# Out:
# array([10., 11., nan, ..., nan, nan, nan])

# %%
list(NFIR_orig)
# Out:
# ['state',
#  'fdid',
#  'inc_no',
#  'city',
#  'street',
#  'zip5',
#  'lat',
#  'lon',
#  'fips',
#  'inc_date',
#  'oth_inj',
#  'oth_death',
#  'exp_no',
#  'inc_type',
#  'prop_loss',
#  'cont_loss',
#  'tot_loss',
#  'detector',
#  'det_type',
#  'det_power',
#  'det_operat',
#  'det_effect',
#  'det_fail',
#  'aes_pres',
#  'aes_type',
#  'aes_oper',
#  'no_spr_op',
#  'aes_fail']

# %%
# munging 

#  recreate the original address catagory to be compatible with the original NFIR file 
NFIR_2['ORIGINAL_ADDRESS'] = NFIR_2['Address'] +', ' + NFIR_2['City'] +', ' + NFIR_2['STATE'] + ', ' + NFIR_2['ZIP']

# set ID as index variable 
NFIR_2 = NFIR_2.set_index('ID')


# Appending All matching NFIR_2 Data to NFIR to create the full geocoded NFIRS dataset
NFIR_all = NFIR.append(NFIR_2.loc[:,'state_fips':], sort = True )

# %%
NFIR_all.tail()
# Out:
#                       ALAND    AWATER  BLKGRPCE  COUNTYFP FUNCSTAT  \
# ID
# rcp2_id1753662    3693813.0   50362.0       2.0      11.0        S
# rcp2_id1332366  227231790.0  186698.0       1.0     215.0        S
# rcp2_id1332364  227231790.0  186698.0       1.0     215.0        S
# rcp2_id1532504     591837.0  167123.0       3.0     275.0        S
# rcp2_id1924543   15335836.0  548613.0       3.0     167.0        S
#
#                        GEOID   INTPTLAT    INTPTLON MATCH MATCHED_ADDRESS  \
# ID
# rcp2_id1753662  4.201101e+11  40.380291  -75.941880   NaN             NaN
# rcp2_id1332366  2.921548e+11  37.207601  -92.156070   NaN             NaN
# rcp2_id1332364  2.921548e+11  37.207601  -92.156070   NaN             NaN
# rcp2_id1532504  2.275000e+10  56.468909 -132.383373   NaN             NaN
# rcp2_id1924543  3.916702e+11  39.399862  -81.252658   NaN             NaN
#
#                 ...                         ORIGINAL_ADDRESS STATE STATEFP  \
# ID              ...
# rcp2_id1753662  ...  ZIEGLERS RD, BERNTOWNSHIP OF, PA, 19605   NaN    42.0
# rcp2_id1332366  ...             ZIMMERMAN, CABOOL, MO, 65689   NaN    29.0
# rcp2_id1332364  ...            ZIMMERMANN, CABOOL, MO, 65689   NaN    29.0
# rcp2_id1532504  ...             ZIMOVIA, WRANGELL, AK, 99929   NaN     2.0
# rcp2_id1924543  ...        ZION RIDGE RD, NEWPORT, OH, 45768   NaN    39.0
#
#                TIGER_LINE_ID TIGER_LINE_SIDE   TRACTCE          X         Y  \
# ID
# rcp2_id1753662           NaN             NaN   12700.0  -75.93677  40.39070
# rcp2_id1332366           NaN             NaN  480400.0  -92.09128  37.15987
# rcp2_id1332364           NaN             NaN  480400.0  -92.09128  37.15987
# rcp2_id1532504           NaN             NaN     300.0 -132.38707  56.47183
# rcp2_id1924543           NaN             NaN   21200.0  -81.26043  39.39918
#
#                    rownum  state_fips
# ID
# rcp2_id1753662  1753662.0        42.0
# rcp2_id1332366  1332366.0        29.0
# rcp2_id1332364  1332364.0        29.0
# rcp2_id1532504  1532504.0         2.0
# rcp2_id1924543  1924543.0        39.0
#
# [5 rows x 24 columns]

# %%
NFIR_orig['ID'] = 'rcp2_id' + NFIR_orig.index.astype('str')

# %%
# adding ID to Original data set 

NFIR_orig = NFIR_orig.set_index('ID')


# merging Geocoded dataset with original Dataset
NFIR_merged_final = NFIR_orig.merge(NFIR_all,how='left',left_index = True, right_index = True)

# %%
# row duplication check 
NFIR_merged_final.tail()
# Out:
#                state   fdid   inc_no         city             street   zip5  \
# ID
# rcp2_id1959102    TX  ZC501  0000107       Zapata  867 Loma Verde RD  78076
# rcp2_id1959103    TX  ZC501  0000013       zapata    706 12th avenue  78076
# rcp2_id1959104    TX  ZC501  0000049       Zapata      231 Davis Ave  78076
# rcp2_id1959105    TX  ZC501  0000072  San Ygnacio   405 Grant street  78067
# rcp2_id1959106    TX  ZC501  0000098       Zapata       709 Ramireno  78076
#
#                 lat  lon  fips            inc_date  ...  \
# ID                                                  ...
# rcp2_id1959102  NaN  NaN   NaN  10/25/2016 0:00:00  ...
# rcp2_id1959103  NaN  NaN   NaN    2/6/2016 0:00:00  ...
# rcp2_id1959104  NaN  NaN   NaN   5/18/2016 0:00:00  ...
# rcp2_id1959105  NaN  NaN   NaN   7/20/2016 0:00:00  ...
# rcp2_id1959106  NaN  NaN   NaN   10/6/2016 0:00:00  ...
#
#                                        ORIGINAL_ADDRESS  STATE  STATEFP  \
# ID
# rcp2_id1959102      867 Loma Verde RD, Zapata, TX,78076     TX     48.0
# rcp2_id1959103        706 12th avenue, zapata, TX,78076     TX     48.0
# rcp2_id1959104                                      NaN    NaN      NaN
# rcp2_id1959105  405 Grant street, San Ygnacio, TX,78067     TX     48.0
# rcp2_id1959106           709 Ramireno, Zapata, TX,78076     TX     48.0
#
#                 TIGER_LINE_ID  TIGER_LINE_SIDE   TRACTCE         X         Y  \
# ID
# rcp2_id1959102    636338770.0                L  950400.0 -99.25941  26.86421
# rcp2_id1959103    185927959.0                R  950302.0 -99.26514  26.91021
# rcp2_id1959104            NaN              NaN       NaN       NaN       NaN
# rcp2_id1959105    185934195.0                L  950400.0 -99.44025  27.04363
# rcp2_id1959106    185927625.0                L  950301.0 -99.26238  26.92053
#
#                rownum state_fips
# ID
# rcp2_id1959102    NaN       48.0
# rcp2_id1959103    NaN       48.0
# rcp2_id1959104    NaN        NaN
# rcp2_id1959105    NaN       48.0
# rcp2_id1959106    NaN       48.0
#
# [5 rows x 52 columns]

# %%
NFIR_merged_final.to_csv('..//Transformed//NFIRS_2009_2016_Combined_CensusBlock.csv')

# %%
NFIR_2.columns
# Out:
# Index(['Address', 'City', 'STATE', 'ZIP', 'X.summary.', 'X.addressee.',
#        'X.delivery_line_1.', 'X.delivery_line_2.', 'X.city_name.',
#        'X.state_abbreviation.', 'X.full_zipcode.', 'X.latitude.',
#        'X.longitude.', 'state_fips', 'COUNTYFP', 'TRACTCE', 'GEOID', 'NAME',
#        'NAMELSAD', 'MTFCC', 'FUNCSTAT', 'X', 'Y', 'rownum', 'STATEFP',
#        'BLKGRPCE', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON',
#        'ORIGINAL_ADDRESS'],
#       dtype='object')

# %%
NFIR_all.columns
# Out:
# Index(['ALAND', 'AWATER', 'BLKGRPCE', 'COUNTYFP', 'FUNCSTAT', 'GEOID',
#        'INTPTLAT', 'INTPTLON', 'MATCH', 'MATCHED_ADDRESS', 'MATCH_TYPE',
#        'MTFCC', 'NAME', 'NAMELSAD', 'ORIGINAL_ADDRESS', 'STATE', 'STATEFP',
#        'TIGER_LINE_ID', 'TIGER_LINE_SIDE', 'TRACTCE', 'X', 'Y', 'rownum',
#        'state_fips'],
#       dtype='object')
