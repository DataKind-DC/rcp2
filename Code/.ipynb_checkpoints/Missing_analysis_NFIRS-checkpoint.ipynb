# %%
# this code takes the NFIRS Dataset and outputs a count of fires by GEOID -
# - The results are functionally the same as fires by census tract but saving by GEOID allows 
# us to combine with shapefiles which use GEOID
#
# requires NFIRS_2009_2016_geocoded_with_tract.csv to be in the main path

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import datetime
import geopandas as gpd
import glob
import seaborn as sns

# %%
# Change to your filepath to data and uncomment if NFIRS_2009_2016_geocoded_with_tract.csv not in the main path 
os.chdir('..//Data//Transformed')
os.getcwd()
# Out:
# '/Users/kelson/Documents/DataKind/Red_Cross_Fire/Data/Transformed'

# %%
# Out:
# Index(['state', 'fdid', 'inc_no', 'city', 'street', 'zip5', 'lat', 'lon',
#        'fips', 'inc_date', 'oth_inj', 'oth_death', 'exp_no', 'inc_type',
#        'prop_loss', 'cont_loss', 'tot_loss', 'detector', 'det_type',
#        'det_power', 'det_operat', 'det_effect', 'det_fail', 'aes_pres',
#        'aes_type', 'aes_oper', 'no_spr_op', 'aes_fail', 'COUNTYFP', 'FUNCSTAT',
#        'GEOID', 'MATCH', 'MATCHED_ADDRESS', 'MATCH_TYPE', 'MTFCC', 'NAME',
#        'NAMELSAD', 'ORIGINAL_ADDRESS', 'STATE', 'TIGER_LINE_ID',
#        'TIGER_LINE_SIDE', 'TRACTCE', 'X', 'Y', 'state_fips'],
#       dtype='object')

# %%
NFIR = pd.read_csv('NFIRS_2009_2016_Combined_Census_Tract.csv',
                   encoding='latin_1',
                   index_col=0,
                   low_memory=False)

# %%
NFIR.head()
# Out:
#          state   fdid inc_no    city            street   zip5  lat  lon  fips  \
# ID
# rcp2_id1    AK  11100    211  JUNEAU    1700 ANGUS WAY  99801  NaN  NaN   NaN
# rcp2_id2    AK  11100    470  JUNEAU  3221 PIONEER AVE  99801  NaN  NaN   NaN
# rcp2_id3    AK  11100    556  JUNEAU   10231 HERON WAY  99801  NaN  NaN   NaN
# rcp2_id4    AK  11100   1315  JUNEAU  6590 GLACIER HWY  99801  NaN  NaN   NaN
# rcp2_id5    AK  11100   2151  JUNEAU  6590 GLACIER HWY  99801  NaN  NaN   NaN
#
#            inc_date    ...      NAME        NAMELSAD  \
# ID                     ...
# rcp2_id1 2009-01-03    ...       5.0  Census Tract 5
# rcp2_id2 2009-01-06    ...       6.0  Census Tract 6
# rcp2_id3 2009-01-06    ...       1.0  Census Tract 1
# rcp2_id4 2009-01-13    ...       4.0  Census Tract 4
# rcp2_id5 2009-01-21    ...       4.0  Census Tract 4
#
#                                ORIGINAL_ADDRESS  STATE  TIGER_LINE_ID  \
# ID
# rcp2_id1      1700 ANGUS WAY, JUNEAU, AK, 99801     AK    190964136.0
# rcp2_id2    3221 PIONEER AVE, JUNEAU, AK, 99801     AK    190966361.0
# rcp2_id3     10231 HERON WAY, JUNEAU, AK, 99801     AK    190962538.0
# rcp2_id4  6590 GLACIER HWY, JUNEAU,  AK,  99801     AK    190963741.0
# rcp2_id5  6590 GLACIER HWY, JUNEAU,  AK,  99801     AK    190963741.0
#
#           TIGER_LINE_SIDE  TRACTCE          X          Y state_fips
# ID
# rcp2_id1                R    500.0 -134.42440  58.306507        2.0
# rcp2_id2                R    600.0 -134.43314  58.292686        2.0
# rcp2_id3                R    100.0 -134.60330  58.402610        2.0
# rcp2_id4                R    400.0 -134.51932  58.358955        2.0
# rcp2_id5                R    400.0 -134.51932  58.358955        2.0
#
# [5 rows x 45 columns]

# %%
NFIR['GEOID'] = NFIR['GEOID'].astype('str')

# %%
 OUT = NFIR.groupby(['GEOID'])['STATE'].count() 
# the selection of state is arbitrary except we know that it should excist in all entries

# %%
OUT.head()
# Out:
# GEOID
# 10001040100.0    16
# 10001040201.0    26
# 10001040202.0    89
# 10001040203.0    90
# 10001040501.0    73
# Name: STATE, dtype: int64

# %%
# Out:
# ['state',
#  'fdid',
#  'inc_no',
#  'city',
#  'street',
#  'zip5',
#  'lat',
#  'lon',
#  'fips',
#  'inc_date',
#  'oth_inj',
#  'oth_death',
#  'exp_no',
#  'inc_type',
#  'prop_loss',
#  'cont_loss',
#  'tot_loss',
#  'detector',
#  'det_type',
#  'det_power',
#  'det_operat',
#  'det_effect',
#  'det_fail',
#  'aes_pres',
#  'aes_type',
#  'aes_oper',
#  'no_spr_op',
#  'aes_fail',
#  'COUNTYFP',
#  'FUNCSTAT',
#  'GEOID',
#  'MATCH',
#  'MATCHED_ADDRESS',
#  'MATCH_TYPE',
#  'MTFCC',
#  'NAME',
#  'NAMELSAD',
#  'ORIGINAL_ADDRESS',
#  'STATE',
#  'TIGER_LINE_ID',
#  'TIGER_LINE_SIDE',
#  'TRACTCE',
#  'X',
#  'Y',
#  'state_fips']

# %%
OUT.to_csv('Fires_by_GEOID.csv',header= True)

# %%
percent_missing = NFIR.isnull().sum() / len(NFIR) * 100 
z =  pd.DataFrame(percent_missing)
z = z.reset_index()
z = z.rename(columns = {0:'Percent Missing'})

# %%
# Out:
#                index       Count
# 0              state    0.006125
# 1               fdid    0.000000
# 2             inc_no    0.000000
# 3               city    0.000408
# 4             street    0.199938
# 5               zip5    0.000357
# 6                lat  100.000000
# 7                lon  100.000000
# 8               fips  100.000000
# 9           inc_date    0.000000
# 10           oth_inj   60.658280
# 11         oth_death   60.658280
# 12            exp_no    0.000000
# 13          inc_type    0.000000
# 14         prop_loss    2.316312
# 15         cont_loss    2.342650
# 16          tot_loss    0.000000
# 17          detector   47.260638
# 18          det_type   76.432260
# 19         det_power   76.183320
# 20        det_operat   76.603716
# 21        det_effect   85.896833
# 22          det_fail   97.219803
# 23          aes_pres   47.260638
# 24          aes_type   98.513046
# 25          aes_oper   98.652293
# 26         no_spr_op   98.818185
# 27          aes_fail   99.830484
# 28          COUNTYFP   16.343934
# 29          FUNCSTAT   20.018519
# 30             GEOID    0.000000
# 31             MATCH   20.018519
# 32   MATCHED_ADDRESS   20.018519
# 33        MATCH_TYPE   20.018519
# 34             MTFCC   20.018519
# 35              NAME   20.018519
# 36          NAMELSAD   20.018519
# 37  ORIGINAL_ADDRESS   16.467052
# 38             STATE   16.343934
# 39     TIGER_LINE_ID   20.018519
# 40   TIGER_LINE_SIDE   20.018519
# 41           TRACTCE   16.343934
# 42                 X   16.343934
# 43                 Y   16.343934
# 44        state_fips   16.343934

# %%
fig, ax =  plt.subplots(figsize= (5,30))
sns.barplot(data = z, y = 'index',x = 'Percent Missing', ax = ax )
