# %%
#  This code takes three NFIRS datasets located in 03_geocodes of the Red Cross google drive
# and combines it into one dataset 
# - Kelson Shilling-Scrivo 2019

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
# Change to your filepath to data and uncomment if NFIRS_2009_2016_geocoded_with_tract.csv not in the main path 
os.chdir('../Data/Raw')

# %%
os.getcwd()
# Out:
# '/Users/kelson/Documents/DataKind/Red_Cross_Fire/Data/Raw'

# %%
# load the data 

# all code is located in the Google Drive under 03_geocodes 
#https://drive.google.com/open?id=1n939Tckv0SFBSiABwIH64M6FSDJHt0eF

# NFIR = automatically geocoded data
# NFIR_2 = handcoded data from Jake 
# NFIR_orig = the original NFIRS dataset


NFIR = pd.read_csv('NFIRS_2009_2016_geocoded_with_tract.csv',
                   encoding='latin_1',
                   index_col=0,
                   low_memory=False)

NFIR_2 = pd.read_csv('NFIRS_2009_2016_FIXED_unique_geocodes_census_tracts.csv',
                   encoding='latin_1',
                   index_col=0,
                   low_memory=False)

NFIR_orig = pd.read_csv('NFIRS_2009_2016.csv',
                   encoding='latin_1',
                   index_col=0,
                   low_memory=False)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
row_count = sum(1 for row in csv.reader( open('NFIRS_2009_2016_geocoded_with_tract.csv' ) ))
row_count2 = sum(1 for row in csv.reader( open('NFIRS_2009_2016_FIXED_unique_geocodes_census_tracts.csv' ) ))

assert(row_count  - NFIR.shape[0] )
assert(row_count2 - NFIR_2.shape[0] )

row_count
# Out:
# 1959106

# %%
##Cleaning 

NFIR.dropna(inplace = True)

# Duplicate checking
dup_flag = set(NFIR.index.values.tolist() ) & set( NFIR_2.index.values.tolist() )

assert( dup_flag == set() )


NFIR_orig.head()
# Out:
#   state   fdid inc_no    city            street   zip5  lat  lon  fips  \
# 1    AK  11100    211  JUNEAU    1700 ANGUS WAY  99801  NaN  NaN   NaN
# 2    AK  11100    470  JUNEAU  3221 PIONEER AVE  99801  NaN  NaN   NaN
# 3    AK  11100    556  JUNEAU   10231 HERON WAY  99801  NaN  NaN   NaN
# 4    AK  11100   1315  JUNEAU  6590 GLACIER HWY  99801  NaN  NaN   NaN
# 5    AK  11100   2151  JUNEAU  6590 GLACIER HWY  99801  NaN  NaN   NaN
#
#             inc_date  ...  det_type  det_power  det_operat  det_effect  \
# 1   1/3/2009 0:00:00  ...         1          1           2           1
# 2   1/6/2009 0:00:00  ...       NaN        NaN         NaN         NaN
# 3   1/6/2009 0:00:00  ...       NaN        NaN         NaN         NaN
# 4  1/13/2009 0:00:00  ...       NaN        NaN         NaN         NaN
# 5  1/21/2009 0:00:00  ...       NaN        NaN         NaN         NaN
#
#    det_fail  aes_pres  aes_type aes_oper no_spr_op aes_fail
# 1       NaN         N       NaN      NaN       NaN      NaN
# 2       NaN       NaN       NaN      NaN       NaN      NaN
# 3       NaN         N       NaN      NaN       NaN      NaN
# 4       NaN       NaN       NaN      NaN       NaN      NaN
# 5       NaN         N       NaN      NaN       NaN      NaN
#
# [5 rows x 28 columns]

# %%
# munging 

#  recreate the original address catagory to be compatible with the original NFIR file 
NFIR_2['ORIGINAL_ADDRESS'] = NFIR_2['Address'] +', ' + NFIR_2['City'] +', ' + NFIR_2['STATE'] + ', ' + NFIR_2['ZIP']

# set ID as index variable 
NFIR_2 = NFIR_2.set_index('ID')


# Appending All matching NFIR_2 Data to NFIR to create the full geocoded NFIRS dataset
NFIR_all = NFIR.append(NFIR_2.loc[:,[ 'ORIGINAL_ADDRESS',
                                     'X','Y','STATE',
                                     'state_fips','COUNTYFP',
                                     'TRACTCE','GEOID']], sort = True )

# %%
NFIR_all.tail()
# Out:
#                 COUNTYFP FUNCSTAT         GEOID MATCH MATCHED_ADDRESS  \
# ID
# rcp2_id1753662      11.0      NaN  4.201101e+10   NaN             NaN
# rcp2_id1332366     215.0      NaN  2.921548e+10   NaN             NaN
# rcp2_id1332364     215.0      NaN  2.921548e+10   NaN             NaN
# rcp2_id1532504     275.0      NaN  2.275000e+09   NaN             NaN
# rcp2_id1924543     167.0      NaN  3.916702e+10   NaN             NaN
#
#                MATCH_TYPE MTFCC  NAME NAMELSAD  \
# ID
# rcp2_id1753662        NaN   NaN   NaN      NaN
# rcp2_id1332366        NaN   NaN   NaN      NaN
# rcp2_id1332364        NaN   NaN   NaN      NaN
# rcp2_id1532504        NaN   NaN   NaN      NaN
# rcp2_id1924543        NaN   NaN   NaN      NaN
#
#                                        ORIGINAL_ADDRESS STATE  TIGER_LINE_ID  \
# ID
# rcp2_id1753662  ZIEGLERS RD, BERNTOWNSHIP OF, PA, 19605    PA            NaN
# rcp2_id1332366             ZIMMERMAN, CABOOL, MO, 65689    MO            NaN
# rcp2_id1332364            ZIMMERMANN, CABOOL, MO, 65689    MO            NaN
# rcp2_id1532504             ZIMOVIA, WRANGELL, AK, 99929    AK            NaN
# rcp2_id1924543        ZION RIDGE RD, NEWPORT, OH, 45768    OH            NaN
#
#                TIGER_LINE_SIDE   TRACTCE          X         Y  state_fips
# ID
# rcp2_id1753662             NaN   12700.0  -75.93677  40.39070        42.0
# rcp2_id1332366             NaN  480400.0  -92.09128  37.15987        29.0
# rcp2_id1332364             NaN  480400.0  -92.09128  37.15987        29.0
# rcp2_id1532504             NaN     300.0 -132.38707  56.47183         2.0
# rcp2_id1924543             NaN   21200.0  -81.26043  39.39918        39.0

# %%
NFIR_orig['ID'] = 'rcp2_id' + NFIR_orig.index.astype('str')

# %%
# adding ID to Original data set 

NFIR_orig = NFIR_orig.set_index('ID')


# merging Geocoded dataset with original Dataset
NFIR_merged_final = NFIR_orig.merge(NFIR_all,how='left',left_index = True, right_index = True)

# %%
# row duplication check 
NFIR_merged_final.head()
# Out:
#          state   fdid inc_no    city            street   zip5  lat  lon  fips  \
# ID
# rcp2_id1    AK  11100    211  JUNEAU    1700 ANGUS WAY  99801  NaN  NaN   NaN
# rcp2_id2    AK  11100    470  JUNEAU  3221 PIONEER AVE  99801  NaN  NaN   NaN
# rcp2_id3    AK  11100    556  JUNEAU   10231 HERON WAY  99801  NaN  NaN   NaN
# rcp2_id4    AK  11100   1315  JUNEAU  6590 GLACIER HWY  99801  NaN  NaN   NaN
# rcp2_id5    AK  11100   2151  JUNEAU  6590 GLACIER HWY  99801  NaN  NaN   NaN
#
#                    inc_date  ...  NAME        NAMELSAD  \
# ID                           ...
# rcp2_id1   1/3/2009 0:00:00  ...   5.0  Census Tract 5
# rcp2_id2   1/6/2009 0:00:00  ...   6.0  Census Tract 6
# rcp2_id3   1/6/2009 0:00:00  ...   1.0  Census Tract 1
# rcp2_id4  1/13/2009 0:00:00  ...   4.0  Census Tract 4
# rcp2_id5  1/21/2009 0:00:00  ...   4.0  Census Tract 4
#
#                                ORIGINAL_ADDRESS  STATE  TIGER_LINE_ID  \
# ID
# rcp2_id1      1700 ANGUS WAY, JUNEAU, AK, 99801     AK    190964136.0
# rcp2_id2    3221 PIONEER AVE, JUNEAU, AK, 99801     AK    190966361.0
# rcp2_id3     10231 HERON WAY, JUNEAU, AK, 99801     AK    190962538.0
# rcp2_id4  6590 GLACIER HWY, JUNEAU,  AK,  99801     AK    190963741.0
# rcp2_id5  6590 GLACIER HWY, JUNEAU,  AK,  99801     AK    190963741.0
#
#           TIGER_LINE_SIDE  TRACTCE          X          Y state_fips
# ID
# rcp2_id1                R    500.0 -134.42440  58.306507        2.0
# rcp2_id2                R    600.0 -134.43314  58.292686        2.0
# rcp2_id3                R    100.0 -134.60330  58.402610        2.0
# rcp2_id4                R    400.0 -134.51932  58.358955        2.0
# rcp2_id5                R    400.0 -134.51932  58.358955        2.0
#
# [5 rows x 45 columns]

# %%
NFIR_merged_final.to_csv('..//Transformed//NFIRS_2009_2016_Combined_Census_Tract.csv')
